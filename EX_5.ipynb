# %% [markdown]
# <a href="https://colab.research.google.com/github/Namee2518/NLP/blob/main/EX_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
# Import ngrams from nltk
from nltk import ngrams

# ---------- Input ----------
sentence = "Natural language processing is interesting"
n = 2 # Change value of n as needed

# ---------- Word N-grams ----------
words = sentence.split()
word_ngrams = ngrams(words, n)

print("Word N-grams:")
for gram in word_ngrams:
    print(gram)

# ---------- Character N-grams ----------
char_ngrams = ngrams(sentence, n)

print("\nCharacter N-grams:")
for gram in char_ngrams:
    print("".join(gram))
# Out:
# Word N-grams:
# ('Natural', 'language')
# ('language', 'processing')
# ('processing', 'is')
# ('is', 'interesting')
#
# Character N-grams:
# Na
# at
# tu
# ur
# ra
# al
# l
#  l
# la
# an
# ng
# gu
# ua
# ag
# ge
# e
#  p
# pr
# ro
# oc
# ce
# es
# ss
# si
# in
# ng
# g
#  i
# is
# s
#  i
# in
# nt
# te
# er
# re
# es
# st
# ti
# in
# ng
