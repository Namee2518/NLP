# %% [markdown]
# <a href="https://colab.research.google.com/github/Namee2518/NLP/blob/main/EX2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def tokenize_text(text):
    tokens = text.split()
    return tokens

text = "Natural Language Processing using Python"
result = tokenize_text(text)

print("Tokens are:")
print(result)
# Out:
# Tokens are:
# ['Natural', 'Language', 'Processing', 'using', 'Python']
