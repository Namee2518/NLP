# %% [markdown]
# <a href="https://colab.research.google.com/github/Namee2518/NLP/blob/main/EX_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def chunk_string(text, size):
    return [text[i:i + size] for i in range(0, len(text), size)]
text = "HelloWorldPython"
chunks = chunk_string(text, 5)
print(chunks)
# Out:
# ['Hello', 'World', 'Pytho', 'n']
