# %% [markdown]
# <a href="https://colab.research.google.com/github/Namee2518/NLP/blob/main/EX_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.tokenize import wordpunct_tokenize
from nltk.stem import PorterStemmer
ps=PorterStemmer()
sentence=input("Enter a sentence:")
words=wordpunct_tokenize(sentence)
print("\nOriginal Words:",words)
stemmed_words=[ps.stem(word)for word in words]
print("Stemmed Words:",stemmed_words)
# Out:
# Enter a sentence:Natural Language Processing
#
# Original Words: ['Natural', 'Language', 'Processing']
# Stemmed Words: ['natur', 'languag', 'process']
